# %% [markdown]
# <a href="https://colab.research.google.com/github/hongatran/testrepoibmcapstone/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('SampleData.csv')

# %%
df.head(5)
# Out:
#    user_id first_order_day most_used_city  count_cuisines  voucher_user  \
# 0  2509520      24/05/2016     Manchester               1             0
# 1  1388390      23/12/2015         London               1             0
# 2  4664154      27/06/2016     Manchester               1             1
# 3  3968328      28/05/2016         London               1             0
# 4  2255524      01/03/2016         London               1             0
#
#    voucher_amount  member_get_member_viral  average_order_value  \
# 0             NaN                      NaN                22.20
# 1             NaN                      NaN                97.20
# 2            10.0                      1.0                35.28
# 3             NaN                      NaN                18.24
# 4             NaN                      NaN                83.04
#
#    cnt_orders_7d_fwd  cnt_orders_14d_fwd  cnt_orders_30d_fwd  \
# 0                  1                   1                   1
# ...
